# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-Stuff" data-toc-modified-id="Import-Stuff-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import Stuff</a></span></li><li><span><a href="#Compare" data-toc-modified-id="Compare-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Compare</a></span></li></ul></div>

# %% [markdown]
# # Import Stuff

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set(font_scale=1.5)

# %%
vacuum_cp = np.array([0.0, 0.06, 0.33, 0.42, 0.52]) # From vacuum/vacuum_comparison.ipynb
beryl_cp = np.array([0.0, 0.07, 0.27, 0.43, 0.52]) # From fine_sweep/analyze_fine_sweep.ipynp

# %% [markdown]
# # Compare

# %%
labels = 'A B C D E'.split()

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.gca()
data = 1*(vacuum_cp-beryl_cp)
sns.barplot(x=labels,y=data,ax=ax)
#sns.lineplot(x=labels,y=data,ax=ax)
ax.axhline(0,color='red')
ax.set(xlabel='Critical Point',ylabel='Angle difference (Vaccum$-$Beryl) [rad]')
# Out:
# [Text(0, 0.5, 'Angle difference (Vaccum$-$Beryl) [rad]'),
#  Text(0.5, 0, 'Critical Point')]
